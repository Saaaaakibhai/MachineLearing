# %% [markdown]
# ## Assignment on Life Expectancy Data

# %% [markdown]
# * Question
# * Analysis
# * Graph
# * Description

# %%
import pandas as pd
df=pd.read_csv('Datasets/Life_Expectancy_Data.csv')
df.info()

# %%
df.head()
# Out:
#    Country          Region  Year  Infant_deaths  Under_five_deaths  \
# 0  Turkiye     Middle East  2015           11.1               13.0
# 1    Spain  European Union  2015            2.7                3.3
# 2    India            Asia  2007           51.5               67.9
# 3   Guyana   South America  2006           32.8               40.5
# 4   Israel     Middle East  2012            3.4                4.3
#
#    Adult_mortality  Alcohol_consumption  Hepatitis_B  Measles   BMI  ...  \
# 0         105.8240                 1.32           97       65  27.8  ...
# 1          57.9025                10.35           97       94  26.0  ...
# 2         201.0765                 1.57           60       35  21.2  ...
# 3         222.1965                 5.68           93       74  25.3  ...
# 4          57.9510                 2.89           97       89  27.0  ...
#
#    Diphtheria  Incidents_HIV  GDP_per_capita  Population_mln  \
# ...

# %% [markdown]
# ### For Save Image

# %%
# code to save the figures as high-res PNGs
import os
from pathlib import Path
from matplotlib import pyplot as plt

IMAGES_PATH = Path() / "ImagesForAssignment/Data_Visualization"
IMAGES_PATH.mkdir(parents=True, exist_ok=True)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = IMAGES_PATH / f"{fig_id}.{fig_extension}"
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# %% [markdown]
# ## Question No 01
# => Region wise life expectancy

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

#creating a count plot using sns

plt.figure(figsize=(18,10))
sns.barplot(data=df, x=df.Region , y=df.Life_expectancy)
plt.title ('Region wish life expectancy')
plt.xlabel("Region")
plt.ylabel("Life_expectancy")
save_fig("Question no 01")
plt.show()

# %% [markdown]
# #### Description of Quesiton no 01

# %% [markdown]
# According to Enviroment,Social Conditions,Quality of life(HDI) every region has different life expectancy and all

# %% [markdown]
# ## Question no 02
# => Alcohol_consumption by year

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#Creating a swarm plot that shows the relation between a categorial and continuous variable
plt.figure(figsize=(15,10))
sns.swarmplot(data=df,x='Year',y='Alcohol_consumption',palette='Set2',size=3)
plt.title('Swam Plot Alcohol_consumption vs BMI')
plt.xlabel('Year')
plt.ylabel('Alcohol_consumption')
#show the fig
save_fig("Swarm Plot Alcohol_consumption vs BMI")
#show the plot
plt.show()
# Out:
# C:\Users\hk305\AppData\Local\Temp\ipykernel_8164\2969212150.py:6: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.swarmplot(data=df,x='Year',y='Alcohol_consumption',palette='Set2',size=3)

# %% [markdown]
# In ths swarmplot we can see that every year this Alcohol_consumption rate being same every year

# %% [markdown]
# ## Question 03
# => Polio Patient By year
